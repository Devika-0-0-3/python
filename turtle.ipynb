# %% [markdown]
# <a href="https://colab.research.google.com/github/Devika-0-0-3/python/blob/main/turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=c76842b2c9589b2e0a7205e584053cbe2583cda583a6c23b16b3d94c4cb39fdb
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
#square
import ColabTurtle.Turtle as t
t.initializeTurtle(initial_speed=5)
for i in range(4):

  t.forward(50)
  t.right(90)
t.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="450.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="200.0" x2="450.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=hidden transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
#hexagon
import ColabTurtle.Turtle as t
t.initializeTurtle(initial_speed=5)
#t.begin_fill()
for i in range(6):
  t.forward(50)
  t.left(60)

#t.filcolor("red")
#t.end_fill()
t.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="356.699" y2="175.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="356.699" y1="175.0" x2="313.398" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.398" y1="200.0" x2="313.398" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.398" y1="250.0" x2="356.699" y2="275.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="356.699" y1="275.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=hidden transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
#star
import ColabTurtle.Turtle as t
t.initializeTurtle(initial_speed=5)
for i in range(5):
  t.forward(50)
  t.right(144)
t.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="429.389" y2="240.451" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="429.389" y1="240.451" x2="381.836" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="381.836" y1="225.0" x2="429.389" y2="209.549" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="429.389" y1="209.549" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=hidden transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
import ColabTurtle.Turtle as t
t.initializeTurtle(initial_speed=5)
for i in range(5):
  t.forward(50)
  t.left(72)
t.hideturtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="352.447" y2="184.549" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="352.447" y1="184.549" x2="323.058" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="323.058" y1="225.0" x2="352.447" y2="265.451" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="352.447" y1="265.451" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=hidden transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...
